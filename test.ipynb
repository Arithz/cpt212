# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('result.csv')

df.columns
# Out:
# Index(['Numberofoperations', ' Lengthofarray'], dtype='object')

# %%
# plot line chart of relationship number of operations by length of array

plt.plot(df['Numberofoperations'], df[' Lengthofarray'], color='red', marker='o')
plt.xlabel('Number of operations')
plt.ylabel('Length of array')
plt.title('Number of operations vs Length of array')
plt.show()
