# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('result.csv')
dfFloat = pd.read_csv('resultFloat.csv')

df.columns
# Out:
# Index(['Number of operations', 'Length of array'], dtype='object')

# %%
# plot line chart of relationship number of operations by length of array

plt.plot(df['Length of array'], df['Number of operations'], color='red', marker='o')
plt.plot( dfFloat['Length of array'], dfFloat['Number of operations'], color='blue', marker='o')
plt.xticks(range(0,1100,100))
plt.grid()
plt.xlabel('Length of array')
plt.ylabel('Number of operations')
plt.title('Number of operations vs Length of array')
plt.show()
